# %% [markdown]
# # Quantum Principal Component Analysis

# %% [markdown]
# In data analysis, it is common to have many features, some of which are redundant or correlated. Often, during data cleaning or data transformation steps, one is interested in reducing the number of features to the few, most important features. One of the way to do that is to capture features with largest variance in the data. To determine which features capture the largest variance is the goal of <i>Principal Component Analysis (PCA) </i>.
#
# Mathematically, this involves taking the raw data and computing the covariance matrix.

# %%
import numpy as np
# Dataset obtained from https://arxiv.org/pdf/1804.03719.pdf
X1 = [4,3,4,4,3,3,3,3,4,4,4,5,4,3,4]
X2 = [3028,1365,2726,2538,1318,1693,1412,1632,2875,3564,4412,4444,4278,3064,3857]
X1 = X1 - np.average(X1)
X2 = (X2 - np.average(X2)) / 1000

# %%
data = np.array([X_1, X_2])
data
# Out:
# array([[ 0.33333333, -0.66666667,  0.33333333,  0.33333333, -0.66666667,
#         -0.66666667, -0.66666667, -0.66666667,  0.33333333,  0.33333333,
#          0.33333333,  1.33333333,  0.33333333, -0.66666667,  0.33333333],
#        [ 0.21426667, -1.44873333, -0.08773333, -0.27573333, -1.49573333,
#         -1.12073333, -1.40173333, -1.18173333,  0.06126667,  0.75026667,
#          1.59826667,  1.63026667,  1.46426667,  0.25026667,  1.04326667]])

# %%
from QPCA import get_covariance_matrix
cov = get_covariance_matrix(data)

print(cov)
# Out:
# [[0.38095238 0.57347619]
#  [0.57347619 1.29693364]]

# %%
from QPCA import get_density_matrix
den = get_density_matrix(cov)
print(den)
# Out:
# [[0.22704306 0.34178495]
#  [0.34178495 0.77295694]]

# %%
from QPCA import purify_density_matrix
pure_den = purify_density_matrix(den)
print(pure_den)
# Out:
# [[-0.22545283 -0.41977861]
#  [ 0.10847494 -0.8724621 ]]

# %%
from braket.circuits import Circuit

# %%
circ = Circuit()
circ.unitary(matrix=pure_den, targets=[1,2])
circ.unitary(matrix=pure_den, targets=[3,4])
circ.h(0)
circ.cswap(0, 1, 3)
circ.h(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-59413d76b554> in <module>
#       1 circ = Circuit()
# ----> 2 circ.unitary(matrix=pure_den, targets=[1,2])
#       3 circ.unitary(matrix=pure_den, targets=[3,4])
#       4 circ.h(0)
#       5 circ.cswap(0, 1, 3)
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/circuit.py in method_from_subroutine(self, *args, **kwargs)
#     103
#     104         def method_from_subroutine(self, *args, **kwargs) -> SubroutineReturn:
# --> 105             return self.add(func, *args, **kwargs)
#     106
#     107         function_name = func.__name__
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/circuit.py in add(self, addable, *args, **kwargs)
#    1039                 self.add_circuit(item, *args, **kwargs)
#    1040             elif callable(item):
# -> 1041                 self.add(item(*args, **kwargs))
#    1042             else:
#    1043                 raise TypeError(f"Cannot add a '{type(item)}' to a Circuit")
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/gates.py in unitary(targets, matrix, display_name)
#    2185         """
#    2186         if 2 ** len(targets) != matrix.shape[0]:
# -> 2187             raise ValueError("Dimensions of the supplied unitary are incompatible with the targets")
#    2188
#    2189         return Instruction(Unitary(matrix, display_name), target=targets)
#
# ValueError: Dimensions of the supplied unitary are incompatible with the targets

# %%
pure_den_reshaped = pure_den.reshape(4)

# %%
Uprep = np.concatenate((pure_den_reshaped, pure_den_reshaped), axis=0)
print(Uprep)
# Out:
# [-0.22545283 -0.41977861  0.10847494 -0.8724621  -0.22545283 -0.41977861
#   0.10847494 -0.8724621 ]

# %%
Uprep = Uprep.reshape(4,2)

# %%
Uprep
# Out:
# array([[-0.22545283, -0.41977861],
#        [ 0.10847494, -0.8724621 ],
#        [-0.22545283, -0.41977861],
#        [ 0.10847494, -0.8724621 ]])

# %%
circ = Circuit()
circ.unitary(matrix=Uprep, targets=[1,2])
circ.unitary(matrix=Uprep, targets=[3,4])
circ.h(0)
circ.cswap(0, 1, 3)
circ.h(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-72dde116de2d> in <module>
#       1 circ = Circuit()
# ----> 2 circ.unitary(matrix=Uprep, targets=[1,2])
#       3 circ.unitary(matrix=Uprep, targets=[3,4])
#       4 circ.h(0)
#       5 circ.cswap(0, 1, 3)
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/circuit.py in method_from_subroutine(self, *args, **kwargs)
#     103
#     104         def method_from_subroutine(self, *args, **kwargs) -> SubroutineReturn:
# --> 105             return self.add(func, *args, **kwargs)
#     106
#     107         function_name = func.__name__
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/circuit.py in add(self, addable, *args, **kwargs)
#    1039                 self.add_circuit(item, *args, **kwargs)
#    1040             elif callable(item):
# -> 1041                 self.add(item(*args, **kwargs))
#    1042             else:
#    1043                 raise TypeError(f"Cannot add a '{type(item)}' to a Circuit")
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/gates.py in unitary(targets, matrix, display_name)
#    2187             raise ValueError("Dimensions of the supplied unitary are incompatible with the targets")
#    2188
# -> 2189         return Instruction(Unitary(matrix, display_name), target=targets)
#    2190
#    2191
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/gates.py in __init__(self, matrix, display_name)
#    2118
#    2119     def __init__(self, matrix: np.ndarray, display_name: str = "U"):
# -> 2120         verify_quantum_operator_matrix_dimensions(matrix)
#    2121         self._matrix = np.array(matrix, dtype=complex)
#    2122         qubit_count = int(np.log2(self._matrix.shape[0]))
#
# ~/anaconda3/envs/Braket/lib/python3.7/site-packages/braket/circuits/quantum_operator_helpers.py in verify_quantum_operator_matrix_dimensions(matrix)
#      31     """
#      32     if not is_square_matrix(matrix):
# ---> 33         raise ValueError(f"{matrix} is not a two-dimensional square matrix")
#      34
#      35     matrix = np.array(matrix, dtype=complex)
#
# ValueError: [[-0.22545283 -0.41977861]
#  [ 0.10847494 -0.8724621 ]
#  [-0.22545283 -0.41977861]
#  [ 0.10847494 -0.8724621 ]] is not a two-dimensional square matrix
